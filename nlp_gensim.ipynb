# %% [markdown]
# ## Installing  and importing required libraries

# %%
# !pip install -U gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.1.0-cp38-cp38-win_amd64.whl (24.0 MB)
# Requirement already satisfied, skipping upgrade: numpy>=1.17.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from gensim) (1.19.2)
# Collecting Cython==0.29.23
#   Downloading Cython-0.29.23-cp38-cp38-win_amd64.whl (1.7 MB)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from gensim) (1.5.2)
# Installing collected packages: Cython, smart-open, gensim
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.21
#     Uninstalling Cython-0.29.21:
#       Successfully uninstalled Cython-0.29.21
# Successfully installed Cython-0.29.23 gensim-4.1.0 smart-open-5.2.1

# %%
# !pip install -U keras
# Out:
# Collecting keras
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.6.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score
from sklearn.model_selection import train_test_split
import gensim.downloader as api
import gensim
from tensorflow import keras


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import nltk
import string
import re

# %% [markdown]
# _Below command will download a pre-trained w2v model on Wikipedia pages. File is 128Mb, so will take time._

# %%
w2v_wiki = api.load('glove-wiki-gigaword-100')

# %%
#seeing a vector for the word "victor"
w2v_wiki['victor']
# Out:
# array([ 0.34364  , -0.046794 ,  0.18192  , -0.050262 ,  0.87526  ,
#        -0.33039  ,  0.78294  , -0.23179  , -0.35979  , -1.0337   ,
#         0.40359  ,  0.48397  , -0.72324  ,  0.046765 ,  0.26511  ,
#        -0.33097  ,  0.69357  , -0.045868 ,  0.2698   ,  0.49527  ,
#         0.13056  , -0.095836 ,  0.99915  ,  0.097056 , -0.46398  ,
#         0.40895  ,  0.072931 , -0.37482  ,  1.0035   ,  0.73496  ,
#        -0.10795  , -0.076917 , -0.061385 ,  0.29896  , -0.099562 ,
#        -0.4148   ,  0.1317   ,  0.26688  ,  0.038517 , -1.0769   ,
#         0.66625  , -0.24342  , -0.047666 , -0.3902   ,  0.14802  ,
#        -0.29275  , -0.59396  , -0.91602  , -0.28666  ,  0.75782  ,
#         0.81966  , -0.19011  , -0.24243  ,  0.43011  ,  0.64499  ,
#        -1.4213   , -0.60807  ,  0.6863   , -0.018351 , -0.34212  ,
#         0.21337  ,  0.15804  , -0.29021  ,  0.26644  ,  0.31479  ,
#        -0.33131  ,  0.20754  ,  0.5988   , -0.7563   ,  0.55374  ,
#         0.19392  ,  0.11201  , -0.46302  , -0.90231  ,  0.50452  ,
#         0.0079741, -0.68577  , -0.1633   , -0.53567  , -0.078343 ,
#         0.47154  ,  0.15304  , -0.42629  , -0.10324  , -0.41909  ,
#        -0.49878  , -0.41621  , -0.31149  , -0.25308  , -0.8807   ,
#         0.58678  , -0.57358  ,  0.044201 ,  0.87466  , -0.61861  ,
#        -0.042468 , -0.51904  , -0.62798  , -0.43684  , -0.57242  ],
#       dtype=float32)

# %% [markdown]
# _Measuring distance between two similar words. If you compare the below result with the above "dist1", you'll notice that
# "vector" and "scalar" have more closer compared to "vector" and "victor", which tells us that w2v model understands and
# differentiates based on context and not just difference in word spellings._

# %%
# taking mean to for understanding purpose,
# otherwise 100 dimension will be difficult to visualize the distance.
print(np.mean(w2v_wiki['vector'] - w2v_wiki['scalar']))
print(np.mean(w2v_wiki['vector'] - w2v_wiki['victor']))
# Out:
# 0.09825662
# 0.15752597

# %% [markdown]
# ### To check what words  out w2v model has learned.

# %% [markdown]
# _Getting the vector form for each word learned by the model in X_train and forming the array for each text in X_train._

# %% [markdown]
# _But these texts are not of same length, hence the vectors won't be either. ML algorithms expect input features of same length. Hence we'll avg. down all the word vectors in text and get a single 100 dimension vector representing a text. We'll have 100 features, where each row represents a vector for a text._

# %% [markdown]
# ## Below is the implementation of the data using _doc2vec_ model.
# - d2v model converts each doc or text or string or paragraph into a representation of n-dimension vector.
# - This is much easier than w2v model as in w2v model we have to avg out vector repres. of all words in a string/doc to get single repres. of the doc.
# - d2v model generates the vector for the doc in a much sophisticated way compared to just avg. out the vectors of all words as in w2v model. So it may prove to be stronger than w2v model.
#
# -----------------------------------------------
#
# - _First we have to tag the documents/texts in order to inform d2v model about individual docs while training._
# - _Simplest way is to just use the index of each text, but there are other methods as well_

# %% [markdown]
# - We are passing the tag as a list as that's how the tagging model expects the tag numbers.

# %% [markdown]
# - You cannot view the vector for a single word as the model is trained to understand docs containing minimum 2 words.

# %% [markdown]
# - Below we are retrieving the vectors for each text in X_test.
# - Note :- In w2v model, we stored the vectors in arrays as we had to perform element-wise mean operation on those vectors. Here
# we dont have to do that so we'll directly store them in lists.
# - Infer_vector is not deterministic i.e. they won't give you same vectors every time you run them.

# %% [markdown]
# ## Defining a function to clean the text messages :-
# - It will remove the punctuation
# - Remove special characters
# - Remove stopwords

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
def clean_text(text):
    t1 = "".join([word.lower() for word in text if word not in string.punctuation])
    t2 = re.split('\W+',t1)
    clean_txt = [word for word in t2 if word not in stopwords]
    return clean_txt

# %% [markdown]
# ## Reading in the data and applying the cleaning function

# %%
messages = pd.read_csv('spam.csv', encoding = 'latin-1')
messages.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis = 1, inplace=True)
messages.columns = ['labels', 'text']

messages.labels = np.where(messages['labels'] == 'spam', 1,0)

messages['txt_clean'] = messages['text'].apply(lambda x : clean_text(x) )
messages.head()
# Out:
#    labels                                               text  \
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...
#
#                                            txt_clean
# 0  [go, jurong, point, crazy, available, bugis, n...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3      [u, dun, say, early, hor, u, c, already, say]
# 4  [nah, dont, think, goes, usf, lives, around, t...

# %% [markdown]
# ## Splitting data into train and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(messages['txt_clean'],messages['labels'], test_size=0.2)

# %% [markdown]
# ## Preparing data for different models
#
# - Three different vectorization models will be used. TF-IDF from sklearn, word2vec and doc2vec from gensim.
# - _These texts are not of same length, hence the vectors won't be either. ML algorithms expect input features of same length. Hence we'll avg. down all the word vectors in text and get a single 100 dimension vector representing a text. We'll have 100 features, where each row represents a vector for a text._
# - d2v model converts each doc or text or string or paragraph into a representation of n-dimension vector.
# - This is much easier than w2v model as in w2v model we have to avg out vector repres. of all words in a string/doc to get single repres. of the doc.
# - d2v model generates the vector for the doc in a much sophisticated way compared to just avg. out the vectors of all words as in w2v model. So it may prove to be stronger than w2v model.
# - _First we have to tag the documents/texts in order to inform d2v model about individual docs while training._
# - _Simplest way is to just use the index of each text, but there are other methods as well_

# %% [markdown]
# _TFIDF won't work on pd series. So in order to trick the vectorizer, we'll just pass our clean text function in analyzer._

# %%
tfidf = TfidfVectorizer(analyzer = clean_text)
tfidf_fit = tfidf.fit(X_train)
X_train_tfidf = tfidf.transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %% [markdown]
# _For word2vec_

# %%
w2v = gensim.models.Word2Vec(X_train, vector_size=100, window=5, min_count=2)

# %%
X_train_vect = np.array([np.array([w2v.wv[i] for i in ls if i in w2v.wv.index_to_key]) for ls in X_train])
X_test_vect = np.array([np.array([w2v.wv[i] for i in ls if i in w2v.wv.index_to_key]) for ls in X_test])
# Out:
# <ipython-input-13-88d3a6f34a96>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   X_train_vect = np.array([np.array([w2v.wv[i] for i in ls if i in w2v.wv.index_to_key]) for ls in X_train])
# <ipython-input-13-88d3a6f34a96>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   X_test_vect = np.array([np.array([w2v.wv[i] for i in ls if i in w2v.wv.index_to_key]) for ls in X_test])

# %%
def avg_vect(w2v_vect):
    
    vect_avg = []

    for vect in w2v_vect:
        if len(vect) != 0:
            vect_avg.append(vect.mean(axis=0))
        else:
            vect_avg.append(np.zeros(100))
    return vect_avg

# %%
X_train_w2v_avg = avg_vect(X_train_vect)
X_test_w2v_avg = avg_vect(X_test_vect)

# %% [markdown]
# _For doc2vec_

# %%
tag_train = [gensim.models.doc2vec.TaggedDocument(v,[i]) for i,v in enumerate(X_train)]
tag_test = [gensim.models.doc2vec.TaggedDocument(v,[i]) for i,v in enumerate(X_test)]

# %%
tag_train
# Out:
# [TaggedDocument(words=['lasting', 'much', '2', 'hours', 'might', 'get', 'lucky'], tags=[0]),
#  TaggedDocument(words=['nope', 'waiting', 'sch', '4', 'daddy', ''], tags=[1]),
#  TaggedDocument(words=['sorry', 'missed', 'call', 'please', 'call', 'back'], tags=[2]),
#  TaggedDocument(words=['dont', 'file', 'bagi', 'work', 'called', 'mei', 'tell', 'find', 'anything', 'room'], tags=[3]),
#  TaggedDocument(words=['cool', 'come', 'havent', 'wined', 'dined'], tags=[4]),
#  TaggedDocument(words=['one', 'joys', 'lifeis', 'waking', 'daywith', 'thoughts', 'somewheresomeone', 'cares', 'enough', 'tosend', 'warm', 'morning', 'greeting', ''], tags=[5]),
#  TaggedDocument(words=['okies', 'ill', 'go', 'yan', 'jiu', 'skip', 'ard', 'oso', 'go', 'cine', 'den', 'go', 'mrt', 'one', 'blah', 'blah', 'blah', ''], tags=[6]),
#  TaggedDocument(words=['latest', 'news', 'police', 'station', 'toilet', 'stolen', 'cops', 'nothing', 'go'], tags=[7]),
#  TaggedDocument(words=['ìï', 'log', '4', 'wat', 'sdryb8i'], tags=[8]),
#  TaggedDocument(words=['cos', 'darren', 'say', 'ì', 'considering', 'mah', 'ask', 'ì'], tags=[9]),
#  TaggedDocument(words=['xclusiveclubsaisai', '2morow', '285', 'soiree', 'speciale', 'zouk', 'nichols', 'parisfree', 'roses', '2', 'ladies', 'info', '0794674629107880867867', ''], tags=[10]),
#  TaggedDocument(words=['û', 'got', 'salt', 'rub', 'open', 'wounds', 'like'], tags=[11]),
#  TaggedDocument(words=['kent', 'vale', 'lor', 'ìï', 'wait', '4', 'ar'], tags=[12]),
#  TaggedDocument(words=['sore', 'throat', 'scratches', 'talk'], tags=[13]),
#  TaggedDocument(words=['donno', 'scorable'], tags=[14]),
#  TaggedDocument(words=['said', 'u', 'mind', 'go', 'bedroom', 'minute', 'ok', 'sed', 'sexy', 'mood', 'came', '5', 'minuts', 'latr', 'wid', 'caken', 'wife'], tags=[15]),
#  TaggedDocument(words=['7', 'wonders', 'world', '7th', '6th', 'ur', 'style', '5th', 'ur', 'smile', '4th', 'ur', 'personality', '3rd', 'ur', 'nature', '2nd', 'ur', 'sms', '1st', 'ur', 'lovely', 'friendship', 'good', 'morning', 'dear'], tags=[16]),
#  TaggedDocument(words=['u', 'made', 'appointment'], tags=[17]),
#  TaggedDocument(words=['compliments', 'away', 'system', 'side'], tags=[18]),
#  TaggedDocument(words=['men', 'like', 'shorter', 'ladies', 'gaze', 'eyes'], tags=[19]),
#  TaggedDocument(words=['wasnt', 'enough', 'trouble', 'sleeping'], tags=[20]),
#  TaggedDocument(words=['uworld', 'site', 'buying', 'qbank', 'buying', 'self', 'assessment', 'also'], tags=[21]),
#  TaggedDocument(words=['mila', 'age23', 'blonde', 'new', 'uk', 'look', 'sex', 'uk', 'guys', 'u', 'like', 'fun', 'text', 'mtalk', '6986618', '30pptxt', '1st', '5free', 'å', '150', 'increments', 'help08718728876'], tags=[22]),
#  TaggedDocument(words=['hey', 'gals', 'anyone', 'u', 'going', 'e', 'driving', 'centre', 'tmr'], tags=[23]),
#  TaggedDocument(words=['cool', 'last', 'little', 'getting', 'time', 'soon'], tags=[24]),
#  TaggedDocument(words=['', 'two', 'cartons', 'u', 'pleased', 'shelves'], tags=[25]),
#  TaggedDocument(words=['important', 'information', '4', 'orange', 'user', 'today', 'lucky', 'day2find', 'log', 'onto', 'httpwwwurawinnercom', 'theres', 'fantastic', 'surprise', 'awaiting'], tags=[26]),
#  TaggedDocument(words=['guaranteed', 'å', '1000', 'cash', 'å', '2000', 'prize', 'claim', 'yr', 'prize', 'call', 'customer', 'service', 'representative', '08714712394', '10am7pm'], tags=[27]),
#  TaggedDocument(words=['actually', 'mobile', 'full', 'msg', 'work', 'online', 'need', 'send', 'ltgt', 'sent', 'msg', 'wil', 'explain', 'u', 'later'], tags=[28]),
#  TaggedDocument(words=['cthen', 'thk', 'shd', 'b', 'enuff', 'still', 'got', 'conclusion', 'n', 'contents', 'pg', 'n', 'references', 'ill', 'b', 'da', 'contents', 'pg', 'n', 'cover', 'pg'], tags=[29]),
#  TaggedDocument(words=['ard', '530', 'like', 'dat', 'lor', 'juz', 'meet', 'mrt', 'station', 'ì', 'dun', 'haf', 'come'], tags=[30]),
#  TaggedDocument(words=['happen'], tags=[31]),
#  TaggedDocument(words=['date', 'sunday'], tags=[32]),
#  TaggedDocument(words=['hello', 'beautiful', 'r', 'u', 'ok', 'ive', 'kinda', 'ad', 'row', 'wiv', 'walked', 'pub', 'wanted', 'night', 'wiv', 'u', 'miss', 'u', ''], tags=[33]),
#  TaggedDocument(words=['sucks', 'ill', 'go', 'u', 'hair', 'youll', 'free', 'right'], tags=[34]),
#  TaggedDocument(words=['awesome', 'text', 'youre', 'restocked'], tags=[35]),
#  TaggedDocument(words=['havent', 'got', 'da', 'topic', 'yet', 'rite'], tags=[36]),
#  TaggedDocument(words=['maybe', 'westshore', 'hyde', 'park', 'village', 'place', 'near', 'house'], tags=[37]),
#  TaggedDocument(words=['ya', 'telling', 'abt', 'tht', 'incident'], tags=[38]),
#  TaggedDocument(words=['em', 'olowoyey', 'uscedu', 'great', 'time', 'argentina', 'sad', 'secretary', 'everything', 'blessing'], tags=[39]),
#  TaggedDocument(words=['thinking', 'u', 'x'], tags=[40]),
#  TaggedDocument(words=['cant', 'pick', 'phone', 'right', 'pls', 'send', 'message'], tags=[41]),
#  TaggedDocument(words=['put', 'sign', 'choose', 'number', 'pin', 'show', 'right'], tags=[42]),
#  TaggedDocument(words=['shall', 'fine', 'avalarr', 'hollalater'], tags=[43]),
#  TaggedDocument(words=['long', 'take', 'get'], tags=[44]),
#  TaggedDocument(words=['going', 'wipro', 'interview', 'today'], tags=[45]),
#  TaggedDocument(words=['gonna', 'death', 'im', 'gonna', 'leave', 'note', 'says', 'robs', 'fault', 'avenge'], tags=[46]),
#  TaggedDocument(words=['wait', '4', 'ì', 'inside', 'da', 'car', 'park'], tags=[47]),
#  TaggedDocument(words=['pls', 'make', 'note', 'shes', 'exposed', 'also', 'find', 'school', 'anyone', 'else', 'vomiting', 'dog', 'cat', 'house', 'let', 'know', 'later'], tags=[48]),
#  TaggedDocument(words=['hi', 'babe', 'thanks', 'coming', 'even', 'though', 'didnt', 'go', 'welli', 'wanted', 'bed', 'hope', 'see', 'soon', 'love', 'kisses', 'xxx'], tags=[49]),
#  TaggedDocument(words=['reached', 'home', 'tired', 'come', 'tomorro'], tags=[50]),
#  TaggedDocument(words=['ok', 'going', 'sleep', 'hope', 'meet'], tags=[51]),
#  TaggedDocument(words=['im', 'home', 'please', 'call'], tags=[52]),
#  TaggedDocument(words=['ard', '4', 'lor'], tags=[53]),
#  TaggedDocument(words=['hey', 'missed', 'tm', 'last', 'night', 'phone', 'charge', 'smiles', 'meeting', 'friend', 'shortly'], tags=[54]),
#  TaggedDocument(words=['dont', 'shall', 'buy', 'one', 'dear'], tags=[55]),
#  TaggedDocument(words=['im', 'freezing', 'craving', 'ice', 'fml'], tags=[56]),
#  TaggedDocument(words=['ill', 'b', 'soon'], tags=[57]),
#  TaggedDocument(words=['get', 'door', 'im'], tags=[58]),
#  TaggedDocument(words=['û', 'look', 'frying', 'pan', 'case', 'û', 'cheap', 'book', 'perhaps', 'û', 'silly', 'frying', 'pan', 'û', 'likely', 'book'], tags=[59]),
#  TaggedDocument(words=['sounds', 'better', 'evening', 'im', 'costume', 'im', 'sure', 'time', 'finish', 'tomorrow', 'txt', 'end'], tags=[60]),
#  TaggedDocument(words=['im', 'class', 'get', 'text'], tags=[61]),
#  TaggedDocument(words=['ok', 'anybody', 'asks', 'abt', 'u', 'tel', 'themp'], tags=[62]),
#  TaggedDocument(words=['u', 'coming', 'back', '4', 'dinner', 'rite', 'dad', 'ask', 'confirm', 'wif', 'u'], tags=[63]),
#  TaggedDocument(words=['10', 'min', 'later', 'k'], tags=[64]),
#  TaggedDocument(words=['ok', 'msg', 'u', 'b4', 'leave', 'house'], tags=[65]),
#  TaggedDocument(words=['anything', 'special'], tags=[66]),
#  TaggedDocument(words=['babe', 'goes', 'day', 'sip', 'cappuccino', 'think', 'love', 'send', 'kiss', 'across', 'sea'], tags=[67]),
#  TaggedDocument(words=['samus', 'shoulders', 'yet'], tags=[68]),
#  TaggedDocument(words=['great', 'new', 'offer', 'double', 'mins', 'double', 'txt', 'best', 'orange', 'tariffs', 'get', 'latest', 'camera', 'phones', '4', 'free', 'call', 'mobileupd8', 'free', '08000839402', '2stoptxt', 'tcs'], tags=[69]),
#  TaggedDocument(words=['want', 'custom', 'officer', 'discount', 'oh'], tags=[70]),
#  TaggedDocument(words=['hoping', 'get', 'away', '7', 'langport', 'still', 'town', 'tonight'], tags=[71]),
#  TaggedDocument(words=['im', 'putting', 'ready', 'lttimegt', ''], tags=[72]),
#  TaggedDocument(words=['thank', 'much', 'skyped', 'wit', 'kz', 'sura', 'didnt', 'get', 'pleasure', 'company', 'hope', 'good', 'weve', 'given', 'ultimatum', 'oh', 'countin', 'aburo', 'enjoy', 'message', 'sent', 'days', 'ago'], tags=[73]),
#  TaggedDocument(words=['free', 'today', 'haf', '2', 'pick', 'parents', 'tonite'], tags=[74]),
#  TaggedDocument(words=['sister', 'belongs', '2', 'family', 'hope', 'tomorrow', 'pray', '4', 'herwho', 'fated', '4', 'shoranur', 'train', 'incident', 'lets', 'hold', 'hands', 'together', 'amp', 'fuelled', 'love', 'amp', 'concern', 'prior', '2', 'grief', 'amp', 'pain', 'pls', 'join', 'dis', 'chain', 'amp', 'pass', 'stop', 'violence', 'women'], tags=[75]),
#  TaggedDocument(words=['shes', 'currently', 'scotland'], tags=[76]),
#  TaggedDocument(words=['dear', '0776xxxxxxx', 'uve', 'invited', 'xchat', 'final', 'attempt', 'contact', 'u', 'txt', 'chat', '86688', '150pmsgrcvdhgsuite3422landsroww1j6hl', 'ldn', '18yrs'], tags=[77]),
#  TaggedDocument(words=['babes', 'think', 'got', 'ur', 'brolly', 'left', 'english', 'wil', 'bring', '2mrw', '4', 'u', 'luv', 'franxx'], tags=[78]),
#  TaggedDocument(words=['drive', 'read', 'need', 'write'], tags=[79]),
#  TaggedDocument(words=['one', 'talking'], tags=[80]),
#  TaggedDocument(words=['sorry', 'trouble', 'u', 'buy', '4d', 'dad', '1405', '1680', '1843', '2', 'big', '1', 'small', 'sat', 'n', 'sun', 'thanx'], tags=[81]),
#  TaggedDocument(words=['hiya', 'u', 'like', 'hlday', 'pics', 'looked', 'horrible', 'took', 'mo', 'hows', 'camp', 'amrca', 'thing', 'speak', 'soon', 'serena'], tags=[82]),
#  TaggedDocument(words=['urgent', 'ur', 'awarded', 'complimentary', 'trip', 'eurodisinc', 'trav', 'acoentry41', 'å', '1000', 'claim', 'txt', 'dis', '87121', '186å', '150morefrmmob', 'shracomorsglsuplt10', 'ls1', '3aj'], tags=[83]),
#  TaggedDocument(words=['sorry', 'ill', 'call', 'later'], tags=[84]),
#  TaggedDocument(words=['lost', '10', 'kilos', 'today'], tags=[85]),
#  TaggedDocument(words=['tomorrow', 'onwards', 'eve', '6', '3', 'work'], tags=[86]),
#  TaggedDocument(words=['thanx', '4', 'e', 'brownie', 'v', 'nice'], tags=[87]),
#  TaggedDocument(words=['wats', 'dear', 'sleeping', 'ah'], tags=[88]),
#  TaggedDocument(words=['size', 'elephant', 'tablets', 'u', 'shove', 'um', 'ur', 'ass'], tags=[89]),
#  TaggedDocument(words=['hows', 'watch', 'resizing'], tags=[90]),
#  TaggedDocument(words=['happy', 'saying'], tags=[91]),
#  TaggedDocument(words=['', 'im', 'snowboarding', 'trip', 'wondering', 'planning', 'get', 'everyone', 'together', 'befor', 'goa', 'meet', 'greet', 'kind', 'affair', 'cheers', ''], tags=[92]),
#  TaggedDocument(words=['also', 'hi', 'wesley', 'howve'], tags=[93]),
#  TaggedDocument(words=['good', 'afternoon', 'sexy', 'buns', 'goes', 'job', 'search', 'wake', 'first', 'thought', 'always', 'love', 'wish', 'fine', 'happy', 'know', 'adore'], tags=[94]),
#  TaggedDocument(words=['short', 'cute', 'good', 'person'], tags=[95]),
#  TaggedDocument(words=['buy', 'pizza', 'meat', 'lovers', 'supreme', 'u', 'get', 'pick'], tags=[96]),
#  TaggedDocument(words=['sfine', 'anytime', 'best'], tags=[97]),
#  TaggedDocument(words=['im', 'really', 'still', 'tonight', 'babe'], tags=[98]),
#  TaggedDocument(words=['sorry', 'ill', 'call', 'later'], tags=[99]),
#  TaggedDocument(words=['winner', 'u', 'specially', 'selected', '2', 'receive', 'å', '1000', 'cash', '4', 'holiday', 'flights', 'inc', 'speak', 'live', 'operator', '2', 'claim', '0871277810810'], tags=[100]),
#  TaggedDocument(words=['yo', 'watching', 'movie', 'netflix'], tags=[101]),
#  TaggedDocument(words=['said', 'gonna', 'snow', 'start', 'around', '8', '9', 'pm', 'tonite', 'predicting', 'inch', 'accumulation'], tags=[102]),
#  TaggedDocument(words=['going', 'ride', 'bike'], tags=[103]),
#  TaggedDocument(words=['lara', 'said', 'loan', 'ltgt', ''], tags=[104]),
#  TaggedDocument(words=['whatsup', 'dont', 'u', 'want', 'sleep'], tags=[105]),
#  TaggedDocument(words=['sports', 'fans', 'get', 'latest', 'sports', 'news', 'str', '2', 'ur', 'mobile', '1', 'wk', 'free', 'plus', 'free', 'tone', 'txt', 'sport', '8007', 'wwwgetzedcouk', '0870141701216', 'norm', '4txt120p', ''], tags=[106]),
#  TaggedDocument(words=['mobile', 'club', 'choose', 'top', 'quality', 'items', 'mobile', '7cfca1a'], tags=[107]),
#  TaggedDocument(words=['got', 'call', 'landline', 'number', 'asked', 'come', 'anna', 'nagar', 'go', 'afternoon'], tags=[108]),
#  TaggedDocument(words=['thought', 'king', 'hill', 'thing'], tags=[109]),
#  TaggedDocument(words=['ride', 'equally', 'uneventful', 'many', 'pesky', 'cyclists', 'around', 'time', 'night', ''], tags=[110]),
#  TaggedDocument(words=['pls', 'whats', 'full', 'name', 'jokes', 'school', 'cos', 'fees', 'university', 'florida', 'seem', 'actually', 'ltgt', 'k', 'pls', 'holla', 'back'], tags=[111]),
#  TaggedDocument(words=['nah', 'im', 'goin', '2', 'wrks', 'j', 'wot', 'bout', 'u'], tags=[112]),
#  TaggedDocument(words=['office', 'na'], tags=[113]),
#  TaggedDocument(words=['haha', 'okay', 'today', 'weekend', 'leh', ''], tags=[114]),
#  TaggedDocument(words=['checking', 'really', 'miss', 'seeing', 'jeremiah', 'great', 'month'], tags=[115]),
#  TaggedDocument(words=['new', 'theory', 'argument', 'wins', 'situation', 'loses', 'person', 'dont', 'argue', 'ur', 'friends', 'kick', 'amp', 'say', 'im', 'always', 'correct'], tags=[116]),
#  TaggedDocument(words=['rather', 'prominent', 'bite', 'mark', 'right', 'cheek'], tags=[117]),
#  TaggedDocument(words=['much', 'would', 'cost', 'hire', 'hitman'], tags=[118]),
#  TaggedDocument(words=['thts', 'gods', 'gift', 'birds', 'humans', 'hav', 'natural', 'gift', 'frm', 'god'], tags=[119]),
#  TaggedDocument(words=['hey', 'sexy', 'buns', 'told', 'adore', 'loverboy', 'hope', 'remember', 'thank', 'sister', 'law', 'meatballs', 'grins', 'love', 'babe'], tags=[120]),
#  TaggedDocument(words=['hows', 'street', 'end', 'library', 'walk'], tags=[121]),
#  TaggedDocument(words=['number', 'sir'], tags=[122]),
#  TaggedDocument(words=['contacted', 'dating', 'service', 'someone', 'know', 'find', 'call', 'land', 'line', '09050000878', 'pobox45w2tg150p'], tags=[123]),
#  TaggedDocument(words=['fighting', 'world', 'easy', 'u', 'either', 'win', 'lose', 'bt', 'fightng', 'some1', 'close', 'u', 'dificult', 'u', 'lose', 'u', 'lose', 'u', 'win', 'u', 'still', 'lose'], tags=[124]),
#  TaggedDocument(words=['even', 'u', 'dont', 'get', 'trouble', 'convincingjust', 'tel', 'twice', 'tel', 'neglect', 'msgs', 'dont', 'c', 'read', 'itjust', 'dont', 'reply'], tags=[125]),
#  TaggedDocument(words=['hi', 'babe', 'im', 'home', 'wanna', 'something', 'xx'], tags=[126]),
#  TaggedDocument(words=['hi', 'elaine', 'todays', 'meeting', 'confirmed'], tags=[127]),
#  TaggedDocument(words=['wat', 'time', 'ì', 'wan', 'today'], tags=[128]),
#  TaggedDocument(words=['thanks', 'honey', 'still', 'havent', 'heard', 'anything', 'leave', 'bit', 'longer', '2', 'crowd', 'try', 'later', 'great', 'advice', 'thanks', 'hope', 'cardiff', 'still'], tags=[129]),
#  TaggedDocument(words=['alright', 'youre', 'sure', 'let', 'know', 'youre', 'leaving'], tags=[130]),
#  TaggedDocument(words=['yeah', 'get', 'random', 'dude', 'need', 'change', 'info', 'sheets', 'party', 'ltgt', '7', 'never', 'study', 'safe'], tags=[131]),
#  TaggedDocument(words=['3', 'received', 'mobile', 'content', 'enjoy'], tags=[132]),
#  TaggedDocument(words=['hows', 'husband'], tags=[133]),
#  TaggedDocument(words=['set', 'place', 'heart', 'mind', 'mind', 'easily', 'forgets', 'heart', 'always', 'remember', 'wish', 'happy', 'valentines', 'day'], tags=[134]),
#  TaggedDocument(words=['heard', 'u4', 'call', 'night', 'knickers', 'make', 'beg', 'like', 'u', 'last', 'time', '01223585236', 'xx', 'luv', 'nikiyu4net'], tags=[135]),
#  TaggedDocument(words=['slept', 'thinkthis', 'time', 'ltgt', 'pm', 'dangerous'], tags=[136]),
#  TaggedDocument(words=['hurting', 'n', 'meaningful', 'lines', 'ever', 'compromised', 'everything', 'love'], tags=[137]),
#  TaggedDocument(words=['yup'], tags=[138]),
#  TaggedDocument(words=['gr8', 'handle', 'victoria', 'island', 'traffic', 'plus', 'whens', 'album', 'due'], tags=[139]),
#  TaggedDocument(words=['lol', 'alright', 'thinkin', 'haha'], tags=[140]),
#  TaggedDocument(words=['geeeee', 'internet', 'really', 'bad', 'today', 'eh', ''], tags=[141]),
#  TaggedDocument(words=['im', 'happy', 'babe', 'woo', 'hoo', 'party', 'dude'], tags=[142]),
#  TaggedDocument(words=['well', 'theres', 'pattern', 'emerging', 'friends', 'telling', 'drive', 'come', 'smoke', 'telling', 'im', 'weed', 'fiendmake', 'smoke', 'muchimpede', 'things', 'see', 'im', 'hesitant'], tags=[143]),
#  TaggedDocument(words=['come', 'tomorrow', 'di'], tags=[144]),
#  TaggedDocument(words=['still', 'work', 'going', 'onit', 'small', 'house'], tags=[145]),
#  TaggedDocument(words=['sorry', 'im', 'free'], tags=[146]),
#  TaggedDocument(words=['thk', 'shld', 'b', 'ya', 'wana', 'go', '4', 'lessons', 'haha', 'go', 'one', 'whole', 'stretch'], tags=[147]),
#  TaggedDocument(words=['much', 'r', 'ì', 'willing', 'pay'], tags=[148]),
#  TaggedDocument(words=['ditto', 'wont', 'worry', 'saying', 'anything', 'anymore', 'like', 'said', 'last', 'night', 'whatever', 'want', 'ill', 'peace'], tags=[149]),
#  TaggedDocument(words=['hi', 'darlin', 'im', 'way', 'london', 'smashed', 'another', 'driver', 'big', 'dent', 'im', 'really', 'missing', 'u', 'u', 'xxx'], tags=[150]),
#  TaggedDocument(words=['actually', 'nvm', 'got', 'hella', 'cash', 'still', 'ltgt', 'ish'], tags=[151]),
#  TaggedDocument(words=['claire', 'havin', 'borin', 'time', 'alone', 'u', 'wanna', 'cum', '2nite', 'chat', '09099725823', 'hope', '2', 'c', 'u', 'luv', 'claire', 'xx', 'callså', '1minmoremobsemspobox45po139wa'], tags=[152]),
#  TaggedDocument(words=['dont', 'know', 'exactly', 'could', 'ask', 'chechi'], tags=[153]),
#  TaggedDocument(words=['jus', 'finish', 'blowing', 'hair', 'u', 'finish', 'dinner', 'already'], tags=[154]),
#  TaggedDocument(words=['rtking', 'pro', 'video', 'club', 'need', 'help', 'inforingtonekingcouk', 'call', '08701237397', 'must', '16', 'club', 'credits', 'redeemable', 'wwwringtonekingcouk', 'enjoy'], tags=[155]),
#  TaggedDocument(words=['hello', 'yeah', 'ive', 'got', 'bath', 'need', 'hair', 'ill', 'come', 'im', 'done', 'yeah'], tags=[156]),
#  TaggedDocument(words=['dont', 'cancer', 'moms', 'making', 'big', 'deal', 'regular', 'checkup', 'aka', 'pap', 'smear'], tags=[157]),
#  TaggedDocument(words=['sindu', 'got', 'job', 'birla', 'soft', ''], tags=[158]),
#  TaggedDocument(words=['waiting', 'call', 'sir'], tags=[159]),
#  TaggedDocument(words=['hows', 'champ', 'leaving', 'glasgow'], tags=[160]),
#  TaggedDocument(words=['pls', 'help', 'tell', 'sura', 'im', 'expecting', 'battery', 'hont', 'pls', 'send', 'message', 'download', 'movies', 'thanks'], tags=[161]),
#  TaggedDocument(words=['im', 'leaving', 'house'], tags=[162]),
#  TaggedDocument(words=['twenty', 'past', 'five', 'said', 'train', 'durham', 'already', 'coz', 'reserved', 'seat'], tags=[163]),
#  TaggedDocument(words=['much', 'better', 'thanks', 'lol'], tags=[164]),
#  TaggedDocument(words=['loan', 'purpose', 'å', '500', 'å', '75000', 'homeowners', 'tenants', 'welcome', 'previously', 'refused', 'still', 'help', 'call', 'free', '0800', '1956669', 'text', 'back', 'help'], tags=[165]),
#  TaggedDocument(words=['ok'], tags=[166]),
#  TaggedDocument(words=['good', 'day', 'mine', 'really', 'busy', 'much', 'tomorrow', 'night'], tags=[167]),
#  TaggedDocument(words=['wish', 'u', 'feel', 'alone'], tags=[168]),
#  TaggedDocument(words=['dont', 'run', 'away', 'frm', 'u', 'walk', 'slowly', 'amp', 'kills', 'u', 'dont', 'care', 'enough', 'stop'], tags=[169]),
#  TaggedDocument(words=['4', 'costa', 'del', 'sol', 'holiday', 'å', '5000', 'await', 'collection', 'call', '09050090044', 'toclaim', 'sae', 'tc', 'pobox334', 'stockport', 'sk38xh', 'costå', '150pm', 'max10mins'], tags=[170]),
#  TaggedDocument(words=['hide', 'anythiing', 'keeping', 'distance'], tags=[171]),
#  TaggedDocument(words=['k', '2marrow', 'coming', 'class'], tags=[172]),
#  TaggedDocument(words=['orange', 'brings', 'ringtones', 'time', 'chart', 'heroes', 'free', 'hit', 'week', 'go', 'ringtones', 'pics', 'wap', 'stop', 'receiving', 'tips', 'reply', 'stop'], tags=[173]),
#  TaggedDocument(words=['probably', 'couple', 'hours', 'tops'], tags=[174]),
#  TaggedDocument(words=['thought', 'praps', 'meant', 'another', 'one', 'goodo', 'ill', 'look', 'tomorrow', ''], tags=[175]),
#  TaggedDocument(words=['really', 'dude', 'friends', 'im', 'afraid', ''], tags=[176]),
#  TaggedDocument(words=['time', 'n', 'smile', 'r', 'two', 'crucial', 'things', 'life', 'sometimes', 'time', 'makes', 'us', 'forget', 'smile', 'sometimes', 'someones', 'smile', 'makes', 'us', 'forget', 'time', 'gud', 'noon'], tags=[177]),
#  TaggedDocument(words=['actually', 'fuck', 'whatever', 'find', 'excuse', 'tampa', 'point', 'january', 'though'], tags=[178]),
#  TaggedDocument(words=['problem', 'talk', 'later'], tags=[179]),
#  TaggedDocument(words=['change', 'fb', 'jaykwon', 'thuglyfe', 'falconerf'], tags=[180]),
#  TaggedDocument(words=['want', '750', 'anytime', 'network', 'mins', '150', 'text', 'new', 'video', 'phone', 'five', 'pounds', 'per', 'week', 'call', '08000776320', 'reply', 'delivery', 'tomorrow'], tags=[181]),
#  TaggedDocument(words=['impossible', 'argue', 'always', 'treats', 'like', 'sub', 'like', 'never', 'released', 'remind', 'necessary'], tags=[182]),
#  TaggedDocument(words=['449071512431', 'urgent', '2nd', 'attempt', 'contact', 'uu', 'å', '1250', 'call', '09071512433', 'b4', '050703', 'tcsbcm4235wc1n3xx', 'callcost', '150ppm', 'mobilesvary', 'maxå', '7', '50'], tags=[183]),
#  TaggedDocument(words=['ok'], tags=[184]),
#  TaggedDocument(words=['holding'], tags=[185]),
#  TaggedDocument(words=['alright', 'babe'], tags=[186]),
#  TaggedDocument(words=['didt', 'play', 'one', 'day', 'last', 'year', 'know', 'even', 'though', 'good', 'team', 'like', 'india'], tags=[187]),
#  TaggedDocument(words=['haha', 'yeah', 'see', 'sec'], tags=[188]),
#  TaggedDocument(words=['leave', 'u', 'always', 'ignorant'], tags=[189]),
#  TaggedDocument(words=['kallis', 'ready', 'bat', '2nd', 'innings'], tags=[190]),
#  TaggedDocument(words=['ok', 'help', 'ask', 'shes', 'working', 'tmr'], tags=[191]),
#  TaggedDocument(words=['cant', 'think', 'anyone', 'spare', 'room', 'top', 'head'], tags=[192]),
#  TaggedDocument(words=['arent', 'coming', 'home', 'class', 'right', 'need', 'work', 'shower'], tags=[193]),
#  TaggedDocument(words=['shop', 'till', 'u', 'drop', 'either', '10k', '5k', 'å', '500', 'cash', 'å', '100', 'travel', 'voucher', 'call', '09064011000', 'ntt', 'po', 'box', 'cr01327bt', 'fixedline', 'cost', '150ppm', 'mobile', 'vary'], tags=[194]),
#  TaggedDocument(words=['friendship', 'game', 'play', 'word', 'say', 'doesnt', 'start', 'march', 'ends', 'may', 'tomorrow', 'yesterday', 'today', 'e'], tags=[195]),
#  TaggedDocument(words=['got', 'shitload', 'diamonds', 'though'], tags=[196]),
#  TaggedDocument(words=['ive', 'told', 'ive', 'returned', 'order'], tags=[197]),
#  TaggedDocument(words=['free', 'nokia', 'motorola', 'upto', '12mths', '12price', 'linerental', '500', 'free', 'xnet', 'mins100txtmth', 'free', 'btooth', 'call', 'mobileupd8', '08001950382', 'call', '2optoutd3wv'], tags=[198]),
#  TaggedDocument(words=['drug', 'able', 'eat'], tags=[199]),
#  TaggedDocument(words=['time', 'tell', 'friend', 'around'], tags=[200]),
#  TaggedDocument(words=['im', 'class', 'holla', 'later'], tags=[201]),
#  TaggedDocument(words=['come', 'sec', 'theres', 'somebody', 'want', 'see'], tags=[202]),
#  TaggedDocument(words=['lol', 'oh', 'babe', 'wont', 'sliding', 'place', 'midnight', 'thanks', 'invite'], tags=[203]),
#  TaggedDocument(words=['cha', 'quiteamuzing', 'thatåõscool', 'babe'], tags=[204]),
#  TaggedDocument(words=['howz', 'painit', 'come', 'todaydo', 'said', 'ystrdayice', 'medicine'], tags=[205]),
#  TaggedDocument(words=['borrow', 'ur', 'bag', 'ok'], tags=[206]),
#  TaggedDocument(words=['lifted', 'hopes', 'offer', 'money', 'need', 'especially', 'end', 'month', 'approaches', 'hurts', 'studying', 'anyways', 'gr8', 'weekend'], tags=[207]),
#  TaggedDocument(words=['ok'], tags=[208]),
#  TaggedDocument(words=['nope', 'wif', 'sis', 'lor', 'aft', 'bathing', 'dog', 'bathe', 'looks', 'like', 'going', '2', 'rain', 'soon'], tags=[209]),
#  TaggedDocument(words=['bill', 'letters', 'ûªm', 'expecting', 'one', 'orange', 'ûªt', 'bill', 'may', 'still', 'say', 'orange'], tags=[210]),
#  TaggedDocument(words=['come', 'online', 'today', 'night'], tags=[211]),
#  TaggedDocument(words=['dad', 'says', 'hurry', 'hell'], tags=[212]),
#  TaggedDocument(words=['missed', 'call', 'alert', 'numbers', 'called', 'left', 'message', '07008009200'], tags=[213]),
#  TaggedDocument(words=['pls', 'go', 'ahead', 'watts', 'wanted', 'sure', 'great', 'weekend', 'abiola'], tags=[214]),
#  TaggedDocument(words=['dont', 'know', 'shes', 'getting', 'messages'], tags=[215]),
#  TaggedDocument(words=['sent', 'jd', 'customer', 'service', 'cum', 'accounts', 'executive', 'ur', 'mail', 'id', 'details', 'contact', 'us'], tags=[216]),
#  TaggedDocument(words=['sorry', 'cant', 'help'], tags=[217]),
#  TaggedDocument(words=['im', 'home'], tags=[218]),
#  TaggedDocument(words=['wow', 'didnt', 'think', 'common', 'take', 'back', 'ur', 'freak', 'unless', 'u', 'chop'], tags=[219]),
#  TaggedDocument(words=['goal', 'arsenal', '4', 'henry', '7', 'v', 'liverpool', '2', 'henry', 'scores', 'simple', 'shot', '6', 'yards', 'pass', 'bergkamp', 'give', 'arsenal', '2', 'goal', 'margin', '78', 'mins'], tags=[220]),
#  TaggedDocument(words=['life', 'means', 'lot', 'love', 'life', 'love', 'people', 'life', 'world', 'calls', 'friends', 'call', 'world', 'ge'], tags=[221]),
#  TaggedDocument(words=['goin', 'workout', 'lor', 'muz', 'lose', 'e', 'fats', ''], tags=[222]),
#  TaggedDocument(words=['yes', 'appt'], tags=[223]),
#  TaggedDocument(words=['please', 'protect', 'ethreats', 'sib', 'never', 'asks', 'sensitive', 'information', 'like', 'passwordsatmsms', 'pin', 'thru', 'email', 'never', 'share', 'password', 'anybody'], tags=[224]),
#  TaggedDocument(words=['hows', 'scotland', 'hope', 'showing', 'jjc', 'tendencies', 'take', 'care', 'live', 'dream'], tags=[225]),
#  TaggedDocument(words=['alright', 'omw', 'gotta', 'change', 'order', 'half8th'], tags=[226]),
#  TaggedDocument(words=['eastenders', 'tv', 'quiz', 'flower', 'dot', 'compare', 'violet', 'e', 'tulip', 'f', 'lily', 'txt', 'e', 'f', '84025', '4', 'chance', '2', 'win', 'å', '100', 'cash', 'wkent150p16'], tags=[227]),
#  TaggedDocument(words=['thats', 'love', 'hear', 'v', 'see', 'sundayish'], tags=[228]),
#  TaggedDocument(words=['500', 'new', 'mobiles', '2004', 'must', 'go', 'txt', 'nokia', '89545', 'collect', 'todayfrom', 'å', '1', 'www4tcbiz', '2optout', '08718726270150gbpmtmsg18', 'txtauction'], tags=[229]),
#  TaggedDocument(words=['want', 'cock', 'hubbys', 'away', 'need', 'real', 'man', '2', 'satisfy', 'txt', 'wife', '89938', 'strings', 'action', 'txt', 'stop', '2', 'end', 'txt', 'rec', 'å', '150ea', 'otbox', '731', 'la1', '7ws', ''], tags=[230]),
#  TaggedDocument(words=['taxt', 'massagetiepos', 'argh', 'ok', 'lool'], tags=[231]),
#  TaggedDocument(words=['dun', 'need', 'use', 'dial', 'juz', 'open', 'da', 'browser', 'n', 'surf'], tags=[232]),
#  TaggedDocument(words=['account', 'credited', '500', 'free', 'text', 'messages', 'activate', 'txt', 'word', 'credit', '80488', 'tcs', 'www80488biz'], tags=[233]),
#  TaggedDocument(words=['jordan', 'got', 'voted', 'last', 'nite'], tags=[234]),
#  TaggedDocument(words=['stayin', 'trouble', 'strangersaw', 'dave', 'day', 'heåõs', 'sorted', 'nowstill', 'bloke', 'u', 'gona', 'get', 'girl', 'mrur', 'mum', 'still', 'thinks', 'get', '2getha', ''], tags=[235]),
#  TaggedDocument(words=['wuld', 'without', 'baby', 'thought', 'alone', 'mite', 'break', 'donåõt', 'wanna', 'go', 'crazy', 'everyboy', 'needs', 'lady', 'xxxxxxxx'], tags=[236]),
#  TaggedDocument(words=['sorry', 'datoday', 'wont', 'come', 'playi', 'driving', 'clas'], tags=[237]),
#  TaggedDocument(words=['hmmm', 'imagine', 'youve', 'come', 'home', 'rub', 'feet', 'make', 'dinner', 'help', 'get', 'ready', 'date', 'sure', 'ready', 'kind', 'life', ''], tags=[238]),
#  TaggedDocument(words=['1000', 'cash', '2000', 'prize', 'claim', 'call09050000327', 'tc', 'rstm', 'sw7', '3ss', '150ppm'], tags=[239]),
#  TaggedDocument(words=['hi', 'di', 'yijue', 'meeting', '7', 'pm', 'esaplanade', 'tonight'], tags=[240]),
#  TaggedDocument(words=['smile', 'pleasure', 'smile', 'pain', 'smile', 'trouble', 'pours', 'like', 'rain', 'smile', 'sum1', 'hurts', 'u', 'smile', 'becoz', 'someone', 'still', 'loves', 'see', 'u', 'smiling'], tags=[241]),
#  TaggedDocument(words=['im', 'gonna', 'miss', 'u', 'much'], tags=[242]),
#  TaggedDocument(words=['merry', 'christmas', 'u', 'annie'], tags=[243]),
#  TaggedDocument(words=['ya', 'toldshe', 'asking', 'wats', 'matter'], tags=[244]),
#  TaggedDocument(words=['urgent', 'mobile', 'awarded', 'å', '1500', 'bonus', 'caller', 'prize', '27603', 'final', 'attempt', '2', 'contact', 'u', 'call', '08714714011'], tags=[245]),
#  TaggedDocument(words=['free', 'ringtone', 'text', 'first', '87131', 'poly', 'text', 'get', '87131', 'true', 'tone', 'help', '0845', '2814032', '16', '1st', 'free', 'tones', '3xå', '150pw', 'eå', 'nd', 'txt', 'stop'], tags=[246]),
#  TaggedDocument(words=['k', 'ill', 'call', 'im', 'close'], tags=[247]),
#  TaggedDocument(words=['hey', 'around', 'ive', 'got', 'enough', 'half', 'ten', 'owe'], tags=[248]),
#  TaggedDocument(words=['kkcongratulation', ''], tags=[249]),
#  TaggedDocument(words=['im', 'gloucesterroad', 'uup', 'later'], tags=[250]),
#  TaggedDocument(words=['great', 'shoot', 'big', 'loads', 'get', 'ready'], tags=[251]),
#  TaggedDocument(words=['ur', 'cashbalance', 'currently', '500', 'pounds', 'maximize', 'ur', 'cashin', 'send', 'go', '86688', '150pmsg', 'cc', '08718720201', 'hgsuite3422lands', 'roww1j6hl'], tags=[252]),
#  TaggedDocument(words=['boy', 'late', '2', 'home', 'father', 'power', 'frndship'], tags=[253]),
#  TaggedDocument(words=['oh', 'brand'], tags=[254]),
#  TaggedDocument(words=['u', 'meet', 'ur', 'dream', 'partner', 'soon', 'ur', 'career', '2', 'flyng', 'start', '2', 'find', 'free', 'txt', 'horo', 'followed', 'ur', 'star', 'sign', 'e', 'g', 'horo', 'aries'], tags=[255]),
#  TaggedDocument(words=['sir', 'thats', '8hr', 'trip', 'bus', 'last', 'week', 'another', 'audition', 'next', 'wednesday', 'think', 'might', 'drive', 'time'], tags=[256]),
#  TaggedDocument(words=['oh', 'ya', 'ya', 'remember', 'da', ''], tags=[257]),
#  TaggedDocument(words=['cmon', 'babe', 'make', 'horny', 'turn', 'txt', 'fantasy', 'babe', 'im', 'hot', 'sticky', 'need', 'replies', 'cost', 'å', '150', '2', 'cancel', 'send', 'stop'], tags=[258]),
#  TaggedDocument(words=['theres', 'someone', 'year', 'ltgt', 'toyota', 'camry', 'like', 'mr', 'olayiwolas', 'mileage', 'ltgt', 'kits', 'clean', 'need', 'know', 'much', 'sell', 'raise', 'dough', 'soon', 'landing', 'sell', 'holla', 'back'], tags=[259]),
#  TaggedDocument(words=['watching', 'tv', 'got', 'new', 'job', ''], tags=[260]),
#  TaggedDocument(words=['dunno', 'dad', 'said', 'coming', 'home', '2', 'bring', 'us', '4', 'lunch', 'yup', 'go', 'w', 'u', 'lor', 'call', 'u', 'reach', 'school', 'lor'], tags=[261]),
#  TaggedDocument(words=['available', 'soiree', 'june', '3rd'], tags=[262]),
#  TaggedDocument(words=['win', 'winner', 'mr', 'foley', 'ipod', 'exciting', 'prizes', 'soon', 'keep', 'eye', 'ur', 'mobile', 'visit', 'wwwwin82050couk'], tags=[263]),
#  TaggedDocument(words=['world', 'suffers', 'lot', 'violence', 'bad', 'people', 'silence', 'good', 'people'], tags=[264]),
#  TaggedDocument(words=['nottel', 'software', 'name'], tags=[265]),
#  TaggedDocument(words=['yeah', 'give', 'call', 'youve', 'got', 'minute'], tags=[266]),
#  TaggedDocument(words=['sir', 'need', 'axis', 'bank', 'account', 'bank', 'address'], tags=[267]),
#  TaggedDocument(words=['ìll', 'submitting', 'da', 'project', 'tmr', 'rite'], tags=[268]),
#  TaggedDocument(words=['jolly', 'good', 'way', 'give', 'u', 'tickets', 'sat', 'eve', '730', 'speak', 'x'], tags=[269]),
#  TaggedDocument(words=['always', 'putting', 'business', 'put', 'pictures', 'ass', 'facebook', 'one', 'open', 'people', 'ive', 'ever', 'met', 'would', 'think', 'picture', 'room', 'would', 'hurt', 'make', 'feel', 'violated'], tags=[270]),
#  TaggedDocument(words=['yes', 'chatting'], tags=[271]),
#  TaggedDocument(words=['worlds', 'happiest', 'frnds', 'never', 'characters', 'dey', 'best', 'understanding', 'differences'], tags=[272]),
#  TaggedDocument(words=['ya', 'came', 'ago'], tags=[273]),
#  TaggedDocument(words=['ill', 'hand', 'phone', 'chat', 'wit', 'u'], tags=[274]),
#  TaggedDocument(words=['think', 'ur', 'smart', 'win', 'å', '200', 'week', 'weekly', 'quiz', 'text', 'play', '85222', 'nowtcs', 'winnersclub', 'po', 'box', '84', 'm26', '3uz', '16', 'gbp150week'], tags=[275]),
#  TaggedDocument(words=['mila', 'age23', 'blonde', 'new', 'uk', 'look', 'sex', 'uk', 'guys', 'u', 'like', 'fun', 'text', 'mtalk', '6986618', '30pptxt', '1st', '5free', 'å', '150', 'increments', 'help08718728876'], tags=[276]),
#  TaggedDocument(words=['wasnt', 'well', 'babe', 'swollen', 'glands', 'throat', 'end', ''], tags=[277]),
#  TaggedDocument(words=['affidavit', 'says', 'ltgt', 'e', 'twiggs', 'st', 'division', 'g', 'courtroom', 'ltgt', 'lttimegt', 'ill', 'double', 'check', 'text', 'tomorrow'], tags=[278]),
#  TaggedDocument(words=['lol', 'ok', 'ill', 'try', 'send', 'warned', 'sprint', 'dead', 'slow', 'youll', 'prolly', 'get', 'tomorrow'], tags=[279]),
#  TaggedDocument(words=['okay', 'thought', 'expert'], tags=[280]),
#  TaggedDocument(words=['urgent', 'mobile', 'number', 'awarded', 'å', '2000', 'prize', 'guaranteed', 'call', '09061790121', 'land', 'line', 'claim', '3030', 'valid', '12hrs', '150ppm'], tags=[281]),
#  TaggedDocument(words=['lmao', 'fun'], tags=[282]),
#  TaggedDocument(words=['got', 'gas', 'money', 'chance', 'gang', 'want', 'go', 'grand', 'nature', 'adventure'], tags=[283]),
#  TaggedDocument(words=['little', 'darlings', 'far', 'week', 'need', 'coffee', 'run', 'tomocant', 'believe', 'time', 'week', 'already', 'û'], tags=[284]),
#  TaggedDocument(words=['got', 'hella', 'gas', 'money', 'want', 'go', 'grand', 'nature', 'adventure', 'galileo', 'little', 'bit'], tags=[285]),
#  TaggedDocument(words=['todays', 'voda', 'numbers', 'ending', '5226', 'selected', 'receive', '350', 'award', 'hava', 'match', 'please', 'call', '08712300220', 'quoting', 'claim', 'code', '1131', 'standard', 'rates', 'app', ''], tags=[286]),
#  TaggedDocument(words=['ya', 'ì', 'taking', 'ure', 'practical', 'lessons', 'start', 'june', ''], tags=[287]),
#  TaggedDocument(words=['wont', 'touch', 'permission'], tags=[288]),
#  TaggedDocument(words=['watching', 'surya', 'movie', '6', 'pm', 'vijay', 'movie', 'pokkiri'], tags=[289]),
#  TaggedDocument(words=['youdoing', 'later', 'sar', 'xxx'], tags=[290]),
#  TaggedDocument(words=['hey', 'going', 'lo', 'lesson', 'gym', ''], tags=[291]),
#  TaggedDocument(words=['hi', 'hope', 'ur', 'day', 'good', 'back', 'walk', 'table', 'booked', 'half', 'eight', 'let', 'know', 'ur', 'coming'], tags=[292]),
#  TaggedDocument(words=['thanks', 'yesterday', 'sir', 'wonderful', 'hope', 'enjoyed', 'burial', 'mojibiola'], tags=[293]),
#  TaggedDocument(words=['baaaaaaaabe', 'wake', 'miss', 'crave', 'need'], tags=[294]),
#  TaggedDocument(words=['make', 'squeezed', 'ltgt', 'bucks', 'dad'], tags=[295]),
#  TaggedDocument(words=['sorry', 'battery', 'died', 'come', 'im', 'getting', 'gram', 'wheres', 'place'], tags=[296]),
#  TaggedDocument(words=['customer', 'service', 'announcement', 'recently', 'tried', 'make', 'delivery', 'unable', 'please', 'call', '07099833605', 'reschedule', 'ref9280114'], tags=[297]),
#  TaggedDocument(words=['valued', 'customer', 'pleased', 'advise', 'following', 'recent', 'review', 'mob', 'awarded', 'å', '1500', 'bonus', 'prize', 'call', '09066364589'], tags=[298]),
#  TaggedDocument(words=['hi', 'mom', 'might', 'back', 'later', 'ltgt', ''], tags=[299]),
#  TaggedDocument(words=['want', '2', 'get', 'laid', 'tonight', 'want', 'real', 'dogging', 'locations', 'sent', 'direct', '2', 'ur', 'mob', 'join', 'uks', 'largest', 'dogging', 'network', 'bt', 'txting', 'gravel', '69888', 'nt', 'ec2a', '31pmsg150p'], tags=[300]),
#  TaggedDocument(words=['planned', 'yet', 'going', 'join', 'company', 'jan', '5', 'onlydon', 'know', 'happen'], tags=[301]),
#  TaggedDocument(words=['sfrom', 'training', 'manual', 'show', 'tech', 'processits', 'password', 'reset', 'troubleshooting'], tags=[302]),
#  TaggedDocument(words=['know', 'thinkin', 'malaria', 'relax', 'children', 'cant', 'handle', 'malaria', 'would', 'worse', 'gastroenteritis', 'takes', 'enough', 'replace', 'loss', 'temp', 'reduce', 'give', 'malaria', 'meds', 'vomit', 'self', 'limiting', 'illness', 'means', 'days', 'completely', 'stop'], tags=[303]),
#  TaggedDocument(words=['want', 'tel', 'u', 'one', 'thing', 'u', 'mistake', 'k', 'message', 'sent'], tags=[304]),
#  TaggedDocument(words=['havent', 'seen', 'facebook', 'huh', 'lol'], tags=[305]),
#  TaggedDocument(words=['much', 'u', 'trying', 'get'], tags=[306]),
#  TaggedDocument(words=['thank', 'much', 'skyped', 'wit', 'kz', 'sura', 'didnt', 'get', 'pleasure', 'company', 'hope', 'good', 'weve', 'given', 'ultimatum', 'oh', 'countin', 'aburo', 'enjoy'], tags=[307]),
#  TaggedDocument(words=['anything', 'lar'], tags=[308]),
#  TaggedDocument(words=['u', 'make', 'fb', 'list'], tags=[309]),
#  TaggedDocument(words=['wont', 'move', 'morphine'], tags=[310]),
#  TaggedDocument(words=['oooh', 'bed', 'ridden', 'ey', 'thinking'], tags=[311]),
#  TaggedDocument(words=['oh', 'oh', 'wasted', 'den', 'muz', 'chiong', 'sat', 'n', 'sun', 'liao'], tags=[312]),
#  TaggedDocument(words=['dai', 'da', 'send', 'resume', 'id'], tags=[313]),
#  TaggedDocument(words=['aiyo', 'u', 'always', 'c', 'ex', 'one', 'dunno', 'abt', 'mei', 'reply', 'first', 'time', 'u', 'reply', 'fast', 'lucky', 'workin', 'huh', 'got', 'bao', 'ur', 'sugardad', 'ahgee', ''], tags=[314]),
#  TaggedDocument(words=['asked', '3mobile', '0870', 'chatlines', 'inclu', 'free', 'mins', 'india', 'cust', 'servs', 'sed', 'yes', 'l8er', 'got', 'mega', 'bill', '3', 'dont', 'giv', 'shit', 'bailiff', 'due', 'days', 'å', '250', '3', 'want', 'å', '800'], tags=[315]),
#  TaggedDocument(words=['one', 'doesnt', 'stalk', 'profiles'], tags=[316]),
#  TaggedDocument(words=['anytime'], tags=[317]),
#  TaggedDocument(words=['knew', 'u', 'slept', 'v', 'late', 'yest', 'wake', 'late'], tags=[318]),
#  TaggedDocument(words=['ta', 'jobs', 'available', 'let', 'know', 'please', 'cos', 'really', 'need', 'start', 'working'], tags=[319]),
#  TaggedDocument(words=['ok', 'many', 'buy'], tags=[320]),
#  TaggedDocument(words=['say', 'slowly', 'godi', 'love', 'amp', 'need', 'youclean', 'heart', 'bloodsend', 'ten', 'special', 'people', 'amp', 'u', 'c', 'miracle', 'tomorrow', 'itplspls'], tags=[321]),
#  TaggedDocument(words=['got', 'call', 'landline', 'number', 'asked', 'come', 'anna', 'nagar', 'go', 'afternoon'], tags=[322]),
#  TaggedDocument(words=['ìï', 'mean', 'confirmed', 'tot', 'juz', 'say', 'oni', 'ok', ''], tags=[323]),
#  TaggedDocument(words=['im', 'reading', 'text', 'sent', 'meant', 'joke', 'read', 'light'], tags=[324]),
#  TaggedDocument(words=['yup', 'song', 'bro', 'creative', 'neva', 'test', 'quality', 'said', 'check', 'review', 'online'], tags=[325]),
#  TaggedDocument(words=['callsmessagesmissed', 'calls'], tags=[326]),
#  TaggedDocument(words=['new', 'theory', 'argument', 'wins', 'situation', 'loses', 'person', 'dont', 'argue', 'ur', 'friends', 'kick', 'amp', 'say', 'im', 'always', 'correct'], tags=[327]),
#  TaggedDocument(words=['computer', 'fried', 'essential', 'part', 'dont', 'keep', 'spares', 'fucking', 'idiot', 'roommates', 'looovvve', 'leaving', 'thing', 'running', 'full', 'ltgt', '7'], tags=[328]),
#  TaggedDocument(words=['deep', 'sigh', 'miss', 'really', 'surprised', 'havent', 'gone', 'net', 'cafe', 'yet', 'get', 'dont', 'miss'], tags=[329]),
#  TaggedDocument(words=['sorry', 'sent', 'blank', 'msg', 'yup', 'trying', '2', 'serious', 'studying'], tags=[330]),
#  TaggedDocument(words=['probably', 'wont', 'eat', 'today', 'think', 'im', 'gonna', 'pop', 'weekend', 'u', 'miss'], tags=[331]),
#  TaggedDocument(words=['yeah', 'think', 'use', 'gt', 'atm', 'register', 'sure', 'theres', 'anyway', 'help', 'let', 'know', 'sure', 'ready'], tags=[332]),
#  TaggedDocument(words=['aight', 'thanks', 'comin'], tags=[333]),
#  TaggedDocument(words=['urgent', 'mobile', 'number', 'awarded', 'å', '2000', 'prize', 'guaranteed', 'call', '09058094455', 'land', 'line', 'claim', '3030', 'valid', '12hrs'], tags=[334]),
#  TaggedDocument(words=['call', 'later', 'dont', 'network', 'urgnt', 'sms'], tags=[335]),
#  TaggedDocument(words=['train', 'back', 'northampton', 'im', 'afraid', 'im', 'staying', 'skyving', 'today', 'ho', 'ho', 'around', 'wednesday', 'though', 'fancy', 'comedy', 'club', 'week', 'way'], tags=[336]),
#  TaggedDocument(words=['yes', 'completely', 'formclark', 'also', 'utter', 'waste'], tags=[337]),
#  TaggedDocument(words=['finally', 'match', 'heading', 'towards', 'draw', 'prediction'], tags=[338]),
#  TaggedDocument(words=['aight', '8', 'latest', 'probably', 'closer', '7', 'jay', 'tyler', 'two', 'trips'], tags=[339]),
#  TaggedDocument(words=['dint', 'touch'], tags=[340]),
#  TaggedDocument(words=['hey', 'leave', 'friday', 'wait', 'ask', 'superior', 'tell'], tags=[341]),
#  TaggedDocument(words=['aight', 'tomorrow', 'around', 'ltgt'], tags=[342]),
#  TaggedDocument(words=['stand', 'away', 'doesnt', 'heart', 'ache', 'without', 'dont', 'wonder', 'dont', 'crave', ''], tags=[343]),
#  TaggedDocument(words=['', 'thats', 'v', 'romantic'], tags=[344]),
#  TaggedDocument(words=['evry', 'emotion', 'dsnt', 'hav', 'wordsevry', 'wish', 'dsnt', 'hav', 'prayrs', 'u', 'smiled', 'world', 'wit', 'uothrwise', 'even', 'drop', 'tear', 'dsnt', 'lik', '2', 'stay', 'wit', 'uso', 'b', 'happy', 'good', 'morning', 'keep', 'smiling'], tags=[345]),
#  TaggedDocument(words=['always', 'celebrate', 'nys', 'family', ''], tags=[346]),
#  TaggedDocument(words=['say', 'slowly', 'godi', 'love', 'amp', 'need', 'youclean', 'heart', 'bloodsend', 'ten', 'special', 'people', 'amp', 'u', 'c', 'miracle', 'tomorrow', 'itplspls'], tags=[347]),
#  TaggedDocument(words=['saw', 'guys', 'dolls', 'last', 'night', 'patrick', 'swayze', 'great'], tags=[348]),
#  TaggedDocument(words=['ok', 'thats', 'cool', 'either', 'raglan', 'rd', 'edward', 'rd', 'behind', 'cricket', 'ground', 'gimme', 'ring', 'ur', 'closeby', 'see', 'tuesday'], tags=[349]),
#  TaggedDocument(words=['networking', 'technical', 'support', 'associate'], tags=[350]),
#  TaggedDocument(words=['yet', 'id', 'like', 'keep', 'touch', 'easiest', 'way', 'barcelona', 'way', 'ru', 'house'], tags=[351]),
#  TaggedDocument(words=['tension', 'ahwhat', 'machiany', 'problem'], tags=[352]),
#  TaggedDocument(words=['good', 'night', 'dear', 'sleepwellamptake', 'care'], tags=[353]),
#  TaggedDocument(words=['talk', 'atleast', 'day', 'otherwise', 'miss', 'best', 'friend', 'world', 'shakespeare', 'shesil', 'ltgt'], tags=[354]),
#  TaggedDocument(words=['love', 'working', 'home', ''], tags=[355]),
#  TaggedDocument(words=['boltblue', 'tones', '150p', 'reply', 'poly', 'mono', 'eg', 'poly3', '1', 'cha', 'cha', 'slide', '2', 'yeah', '3', 'slow', 'jamz', '6', 'toxic', '8', 'come', 'stop', '4', 'tones', 'txt'], tags=[356]),
#  TaggedDocument(words=['u', 'find', 'sitter', 'kaitlyn', 'sick', 'slept', 'day', 'yesterday'], tags=[357]),
#  TaggedDocument(words=['wait', 'know', 'wesleys', 'town', 'bet', 'hella', 'drugs'], tags=[358]),
#  TaggedDocument(words=['oh', 'okie', 'lorwe', 'go', 'sat', ''], tags=[359]),
#  TaggedDocument(words=['dont', 'want', 'leave', 'im', 'barely', 'stay', 'sane', 'fighting', 'constantly', 'isnt', 'helping'], tags=[360]),
#  TaggedDocument(words=['certainly', 'puts', 'things', 'perspective', 'something', 'like', 'happens'], tags=[361]),
#  TaggedDocument(words=['awarded', 'sipix', 'digital', 'camera', 'call', '09061221061', 'landline', 'delivery', 'within', '28days', 'cs', 'box177', 'm221bp', '2yr', 'warranty', '150ppm', '16', 'p', 'på', '399'], tags=[362]),
#  TaggedDocument(words=['better', 'bb', 'wont', 'use', 'wife', 'doctor'], tags=[363]),
#  TaggedDocument(words=['doinghow'], tags=[364]),
#  TaggedDocument(words=['wait', 'thats', 'still', 'clear', 'sure', 'sarcastic', 'thats', 'x', 'doesnt', 'want', 'live', 'us'], tags=[365]),
#  TaggedDocument(words=['missing', 'toopray', 'inshah', 'allah'], tags=[366]),
#  TaggedDocument(words=['plz', 'note', 'anyone', 'calling', 'mobile', 'co', 'amp', 'asks', 'u', 'type', 'ltgt', 'ltgt', 'disconnect', 'callcoz', 'iz', 'attempt', 'terrorist', 'make', 'use', 'sim', 'card', 'itz', 'confirmd', 'nokia', 'n', 'motorola', 'n', 'verified', 'cnn', 'ibn'], tags=[367]),
#  TaggedDocument(words=['asked', 'hows', 'anthony', 'dad', 'bf'], tags=[368]),
#  TaggedDocument(words=['spoil', 'bed', 'well', ''], tags=[369]),
#  TaggedDocument(words=['save', 'money', 'wedding', 'lingerie', 'wwwbridalpetticoatdreamscouk', 'choose', 'superb', 'selection', 'national', 'delivery', 'brought', 'weddingfriend'], tags=[370]),
#  TaggedDocument(words=['tell', 'quite', 'long', 'cos', 'havent', 'finish', 'film', 'yet'], tags=[371]),
#  TaggedDocument(words=['free', 'top', 'ringtone', 'sub', 'weekly', 'ringtoneget', '1st', 'week', 'freesend', 'subpoly', '816183', 'per', 'weekstop', 'sms08718727870'], tags=[372]),
#  TaggedDocument(words=['25p', '4', 'alfie', 'moons', 'children', 'need', 'song', 'ur', 'mob', 'tell', 'ur', 'm8s', 'txt', 'tone', 'charity', '8007', 'nokias', 'poly', 'charity', 'polys', 'zed', '08701417012', 'profit', '2', 'charity'], tags=[373]),
#  TaggedDocument(words=['get', 'dump', 'heap', 'mom', 'decided', 'come', 'lowes', 'boring'], tags=[374]),
#  TaggedDocument(words=['urgent', 'trying', 'contact', 'u', 'todays', 'draw', 'shows', 'å', '800', 'prize', 'guaranteed', 'call', '09050001295', 'land', 'line', 'claim', 'a21', 'valid', '12hrs'], tags=[375]),
#  TaggedDocument(words=['bored', 'speed', 'dating', 'try', 'speedchat', 'txt', 'speedchat', '80155', 'dont', 'like', 'em', 'txt', 'swap', 'get', 'new', 'chatter', 'chat80155', 'pobox36504w45wq', '150pmsg', 'rcd', '16'], tags=[376]),
#  TaggedDocument(words=['speak', 'feel', 'words', 'better', 'silence', 'gud', 'mrng'], tags=[377]),
#  TaggedDocument(words=['thanks', 'message', 'really', 'appreciate', 'sacrifice', 'im', 'sure', 'process', 'direct', 'pay', 'find', 'way', 'back', 'test', 'tomorrow', 'im', 'class', 'wonderful', 'day'], tags=[378]),
#  TaggedDocument(words=['nothing', 'ever', 'easy', 'dont', 'looking', 'reason', 'take', 'risk', 'life', 'love'], tags=[379]),
#  TaggedDocument(words=['happen', 'dear', 'tell'], tags=[380]),
#  TaggedDocument(words=['u', 'early'], tags=[381]),
#  TaggedDocument(words=['thts', 'wat', 'wright', 'brother', 'fly'], tags=[382]),
#  TaggedDocument(words=['love', ''], tags=[383]),
#  TaggedDocument(words=['greetings', 'consider', 'excused'], tags=[384]),
#  TaggedDocument(words=['important', 'customer', 'service', 'announcement', 'premier'], tags=[385]),
#  TaggedDocument(words=['check', 'got', 'detailed', 'message'], tags=[386]),
#  TaggedDocument(words=['private', '2004', 'account', 'statement', '07742676969', 'shows', '786', 'unredeemed', 'bonus', 'points', 'claim', 'call', '08719180248', 'identifier', 'code', '45239', 'expires'], tags=[387]),
#  TaggedDocument(words=['wanna', 'gym', 'harri'], tags=[388]),
#  TaggedDocument(words=['back', 'brum', 'thanks', 'putting', 'us', 'keeping', 'us', 'happy', 'see', 'soon', ''], tags=[389]),
#  TaggedDocument(words=['ooooooh', 'forgot', 'tell', 'u', 'get', 'yoville', 'phone'], tags=[390]),
#  TaggedDocument(words=['happy', 'new', 'year', 'u', 'ur', 'familymay', 'new', 'year', 'bring', 'happiness', 'stability', 'tranquility', 'ur', 'vibrant', 'colourful', 'life'], tags=[391]),
#  TaggedDocument(words=['erm', 'û', 'ill', 'pick', '645pm', 'thatll', 'give', 'enough', 'time', 'get', 'park'], tags=[392]),
#  TaggedDocument(words=['lol', 'would', 'mom', 'would', 'fit', 'tell', 'whole', 'family', 'crazy', 'terrible'], tags=[393]),
#  TaggedDocument(words=['', ''], tags=[394]),
#  TaggedDocument(words=['sorry', 'ill', 'call', 'later'], tags=[395]),
#  TaggedDocument(words=['somebody', 'go', 'andros', 'steal', 'ice'], tags=[396]),
#  TaggedDocument(words=['stomach', 'thru', 'much', 'trauma', 'swear', 'cant', 'eat', 'better', 'lose', 'weight'], tags=[397]),
#  TaggedDocument(words=['sms', 'services', 'inclusive', 'text', 'credits', 'pls', 'goto', 'wwwcomuknet', 'login', 'unsubscribe', 'stop', 'extra', 'charge', 'help08700469649', 'po', 'box420', 'ip4', '5we'], tags=[398]),
# ...
#  TaggedDocument(words=['dear', 'uve', 'invited', 'xchat', 'final', 'attempt', 'contact', 'u', 'txt', 'chat', '86688', '150pmsgrcvdhgsuite3422landsroww1j6hl', 'ldn', '18', 'yrs'], tags=[858]),
#  TaggedDocument(words=['mm', 'time', 'dont', 'like', 'fun'], tags=[859]),
#  TaggedDocument(words=['love', 'aathilove', 'u', 'lot'], tags=[860]),
#  TaggedDocument(words=['tried', 'contact', 'reply', 'offer', 'video', 'phone', '750', 'anytime', 'network', 'mins', 'half', 'price', 'line', 'rental', 'camcorder', 'reply', 'call', '08000930705'], tags=[861]),
#  TaggedDocument(words=['cold', 'dont', 'sad', 'dear'], tags=[862]),
#  TaggedDocument(words=['huh', 'lei'], tags=[863]),
#  TaggedDocument(words=['hi', 'ur', 'lookin', '4', 'saucy', 'daytime', 'fun', 'wiv', 'busty', 'married', 'woman', 'free', 'next', 'week', 'chat', '2', 'sort', 'time', '09099726429', 'janinexx', 'callså', '1minmobsmorelkpobox177hp51fl'], tags=[864]),
#  TaggedDocument(words=['omg', 'one', 'thing', 'another', 'cat', 'worms', 'bad', 'day', 'end'], tags=[865]),
#  TaggedDocument(words=['show', 'wot', 'say', 'could', 'u', 'c', '4', 'dust'], tags=[866]),
#  TaggedDocument(words=['dude', 'makin', 'weirdy', 'brownies', 'sister', 'made', 'awesome', 'cookies', 'took', 'pics'], tags=[867]),
#  TaggedDocument(words=['come', 'takes', 'little', 'time', 'child', 'afraid', 'dark', 'become', 'teenager', 'wants', 'stay', 'night'], tags=[868]),
#  TaggedDocument(words=['big', 'brother', 'û', 'really', 'scraped', 'barrel', 'shower', 'social', 'misfits'], tags=[869]),
#  TaggedDocument(words=['yup', 'im', 'still', 'coffee', 'wif', 'frens', 'fren', 'drove', 'shell', 'give', 'lift'], tags=[870]),
#  TaggedDocument(words=['responding'], tags=[871]),
#  TaggedDocument(words=['', 'ltdecimalgt', 'common', 'car', 'better', 'buy', 'china', 'asia', 'find', 'less', 'expensive', 'ill', 'holla'], tags=[872]),
#  TaggedDocument(words=['much', 'cost', 'approx', 'per', 'month'], tags=[873]),
#  TaggedDocument(words=['urgent', 'call', '09066612661', 'landline', 'complementary', '4', 'tenerife', 'holiday', 'å', '10000', 'cash', 'await', 'collection', 'sae', 'tcs', 'po', 'box', '3', 'wa14', '2px', '150ppm', '18', 'sender', 'hol', 'offer'], tags=[874]),
#  TaggedDocument(words=['convey', 'regards'], tags=[875]),
#  TaggedDocument(words=['guessin', 'aint', 'gonna', '9'], tags=[876]),
#  TaggedDocument(words=['oh', 'u', 'must', 'taken', 'real', 'valentine', 'shopping', 'first'], tags=[877]),
#  TaggedDocument(words=['love', 'brother', 'time', 'talk', 'english', 'grins', 'say', 'hey', 'muhommad', 'penny', 'says', 'hello', 'across', 'sea'], tags=[878]),
#  TaggedDocument(words=['wats', 'ur', 'opinion', 'abt', 'abt', 'character'], tags=[879]),
#  TaggedDocument(words=['realise', 'busy', 'guy', 'im', 'trying', 'bother', 'get', 'exams', 'outta', 'way', 'try', 'cars', 'gr8', 'day'], tags=[880]),
#  TaggedDocument(words=['realize', '40', 'years', 'well', 'thousands', 'old', 'ladies', 'running', 'around', 'tattoos'], tags=[881]),
#  TaggedDocument(words=['yo', 'call', 'get', 'chance', 'friend', 'mine', 'wanted', 'ask', 'big', 'order'], tags=[882]),
#  TaggedDocument(words=['dont', 'thnk', 'wrong', 'calling', 'us'], tags=[883]),
#  TaggedDocument(words=['ya', 'nice', 'ready', 'thursday'], tags=[884]),
#  TaggedDocument(words=['ok', 'try', 'week', 'end', 'course', 'coimbatore'], tags=[885]),
#  TaggedDocument(words=['hiya', 'last', 'night', 'ive', 'naughty', 'bought', 'clothes', 'little', 'ready', 'shopping', 'tho', 'kind', 'time', 'wanna', 'meet'], tags=[886]),
#  TaggedDocument(words=['', 'september'], tags=[887]),
#  TaggedDocument(words=['4', 'costa', 'del', 'sol', 'holiday', 'å', '5000', 'await', 'collection', 'call', '09050090044', 'toclaim', 'sae', 'tc', 'pobox334', 'stockport', 'sk38xh', 'costå', '150pm', 'max10mins'], tags=[888]),
#  TaggedDocument(words=['phone', 'weirdest', 'auto', 'correct'], tags=[889]),
#  TaggedDocument(words=['1st', 'wk', 'free', 'gr8', 'tones', 'str8', '2', 'u', 'wk', 'txt', 'nokia', '8007', 'classic', 'nokia', 'tones', 'hit', '8007', 'polys', 'nokia150p', 'poly200p', '16'], tags=[890]),
#  TaggedDocument(words=['wanna', 'gym'], tags=[891]),
#  TaggedDocument(words=['ur', 'paper', 'today', 'e', 'morn', 'aft'], tags=[892]),
#  TaggedDocument(words=['mind', 'blastin', 'tsunamis', 'occur', 'rajnikant', 'stopped', 'swimming', 'indian', 'oceand'], tags=[893]),
#  TaggedDocument(words=['trying', 'find', 'chinese', 'food', 'place', 'around'], tags=[894]),
#  TaggedDocument(words=['cant', 'pick', 'phone', 'right', 'pls', 'send', 'message'], tags=[895]),
#  TaggedDocument(words=['k', 'ill', 'drinkpa', 'need', 'srs', 'model', 'pls', 'send', 'mail', 'id', 'pa'], tags=[896]),
#  TaggedDocument(words=['nah', 'dont', 'think', 'goes', 'usf', 'lives', 'around', 'though'], tags=[897]),
#  TaggedDocument(words=['ok', 'lor', 'go', 'tog', 'lor'], tags=[898]),
#  TaggedDocument(words=['thank', 'generally', 'date', 'brothas'], tags=[899]),
#  TaggedDocument(words=['try', 'something', 'dear', 'read', 'something', 'exams'], tags=[900]),
#  TaggedDocument(words=['welcome', 'please', 'reply', 'age', 'gender', 'begin', 'eg', '24m'], tags=[901]),
#  TaggedDocument(words=['ok', 'bag'], tags=[902]),
#  TaggedDocument(words=['one', 'days', 'billion', 'classes', 'right'], tags=[903]),
#  TaggedDocument(words=['sounds', 'like', 'could', 'lot', 'time', 'spent', 'chastity', 'device', 'boy', 'grins', 'take', 'beatings', 'like', 'good', 'dog', 'going', 'lounge', 'nice', 'long', 'bath', ''], tags=[904]),
#  TaggedDocument(words=['cool', 'tyler', 'take', 'gonna', 'buy', 'drop', 'place', 'later', 'tonight', 'total', 'order', 'quarter', 'got', 'enough'], tags=[905]),
#  TaggedDocument(words=['awesome', 'ill', 'see', 'bit'], tags=[906]),
#  TaggedDocument(words=['im', 'actor', 'work', 'work', 'evening', 'sleep', 'late', 'since', 'im', 'unemployed', 'moment', 'always', 'sleep', 'late', 'youre', 'unemployed', 'every', 'day', 'saturday'], tags=[907]),
#  TaggedDocument(words=['lick', 'every', 'drop', 'ready', 'use', 'mouth', 'well'], tags=[908]),
#  TaggedDocument(words=['haha', 'heard', 'text', 'youre', 'around'], tags=[909]),
#  TaggedDocument(words=['sms', 'ac', 'blind', 'date', '4u', 'rodds1', '21m', 'aberdeen', 'united', 'kingdom', 'check', 'httpimg', 'sms', 'acwicmb3cktz8r74', 'blind', 'dates', 'send', 'hide'], tags=[910]),
#  TaggedDocument(words=['hello', 'baby', 'get', 'back', 'moms', 'setting', 'computer', 'filling', 'belly', 'goes', 'loverboy', 'miss', 'already', 'sighs'], tags=[911]),
#  TaggedDocument(words=['7', 'wonders', 'world', '7th', '6th', 'ur', 'style', '5th', 'ur', 'smile', '4th', 'ur', 'personality', '3rd', 'ur', 'nature', '2nd', 'ur', 'sms', '1st', 'ur', 'lovely', 'friendship', 'good', 'morning', 'dear'], tags=[912]),
#  TaggedDocument(words=['lol', 'would', 'awesome', 'payback'], tags=[913]),
#  TaggedDocument(words=['call', 'plz', 'number', 'shows', 'coveragd', 'area', 'urgnt', 'call', 'vasai', 'amp', 'reach', '4o', 'clock', 'call', 'plz'], tags=[914]),
#  TaggedDocument(words=['oops', 'ltgt', ''], tags=[915]),
#  TaggedDocument(words=['way', 'send', 'shades', 'stuff', 'wonderful'], tags=[916]),
#  TaggedDocument(words=['mm', 'kanji', 'dont', 'eat', 'anything', 'heavy', 'ok'], tags=[917]),
#  TaggedDocument(words=['issues', 'right', 'ill', 'fix', 'tomorrow'], tags=[918]),
#  TaggedDocument(words=['wot', 'u', '2', 'thout', 'u', 'gonna', 'call', 'txt', 'bak', 'luv', 'k'], tags=[919]),
#  TaggedDocument(words=['one', 'interested', 'may', 'business', 'plan'], tags=[920]),
#  TaggedDocument(words=['double', 'mins', 'double', 'txt', '12', 'price', 'linerental', 'latest', 'orange', 'bluetooth', 'mobiles', 'call', 'mobileupd8', 'latest', 'offers', '08000839402', 'call2optoutlf56'], tags=[921]),
#  TaggedDocument(words=['ok', 'ill', 'send', 'ltdecimalgt', 'ok'], tags=[922]),
#  TaggedDocument(words=['av', 'new', 'number', 'wil', 'u', 'use', 'oneta'], tags=[923]),
#  TaggedDocument(words=['nobody', 'names', 'penis', 'girls', 'name', 'story', 'doesnt', 'add'], tags=[924]),
#  TaggedDocument(words=['thanx', 'lot', '4', 'ur', 'help'], tags=[925]),
#  TaggedDocument(words=['alrite', 'jod', 'hows', 'revision', 'goin', 'keris', 'bin', 'doin', 'smidgin', 'n', 'e', 'way', 'u', 'wanna', 'cum', 'collegexx'], tags=[926]),
#  TaggedDocument(words=['u', 'receive', 'msg'], tags=[927]),
#  TaggedDocument(words=['whenre', 'guys', 'getting', 'back', 'g', 'said', 'thinking', 'staying', 'mcr'], tags=[928]),
#  TaggedDocument(words=['told', 'going', 'got', 'drunk'], tags=[929]),
#  TaggedDocument(words=['sir', 'waiting', 'mail'], tags=[930]),
#  TaggedDocument(words=['yeah', 'think', 'usual', 'guys', 'still', 'passed', 'last', 'night', 'get', 'ahold', 'anybody', 'let', 'know', 'ill', 'throw'], tags=[931]),
#  TaggedDocument(words=['lol', 'boo', 'hoping', 'laugh'], tags=[932]),
#  TaggedDocument(words=['went', 'pay', 'rent', 'go', 'bank', 'authorise', 'payment'], tags=[933]),
#  TaggedDocument(words=['dear', 'reach'], tags=[934]),
#  TaggedDocument(words=['hello', 'lover', 'goes', 'new', 'job', 'happy', 'think', 'wake', 'slave', 'send', 'teasing', 'kiss', 'across', 'sea'], tags=[935]),
#  TaggedDocument(words=['yar', 'lor', 'actually', 'quite', 'fast', 'cos', 'da', 'ge', 'slow', 'wat', 'haha'], tags=[936]),
#  TaggedDocument(words=['yep', 'like', 'pink', 'furniture', 'tho'], tags=[937]),
#  TaggedDocument(words=['wasnt', 'paying', 'attention'], tags=[938]),
#  TaggedDocument(words=['know', 'called'], tags=[939]),
#  TaggedDocument(words=['wat', 'ì'], tags=[940]),
#  TaggedDocument(words=['ok', 'chinese', 'food', 'way', 'get', 'fat', 'youre', 'paying', 'lipo'], tags=[941]),
#  TaggedDocument(words=['okie', 'ì', 'wan', 'meet', 'bishan', 'cos', 'bishan', 'im', 'driving', 'today'], tags=[942]),
#  TaggedDocument(words=['glad', 'talking'], tags=[943]),
#  TaggedDocument(words=['really', 'hows', 'masters'], tags=[944]),
#  TaggedDocument(words=['ill', 'meet', 'library'], tags=[945]),
#  TaggedDocument(words=['gas', 'station', 'go'], tags=[946]),
#  TaggedDocument(words=['hmm', 'thinking', 'lor'], tags=[947]),
#  TaggedDocument(words=['youve', 'tkts', 'euro2004', 'cup', 'final', 'å', '800', 'cash', 'collect', 'call', '09058099801', 'b4190604', 'pobox', '7876150ppm'], tags=[948]),
#  TaggedDocument(words=['dare', 'ask', 'luck', 'sorting', 'car'], tags=[949]),
#  TaggedDocument(words=['ok', 'thanx'], tags=[950]),
#  TaggedDocument(words=['yeah', 'like', 'goes', 'like', 'friends', 'imma', 'flip', 'shit', 'like', 'half', 'hour'], tags=[951]),
#  TaggedDocument(words=['todays', 'vodafone', 'numbers', 'ending', '4882', 'selected', 'receive', 'å', '350', 'award', 'number', 'matches', 'call', '09064019014', 'receive', 'å', '350', 'award'], tags=[952]),
#  TaggedDocument(words=['anything', 'valuable', '2', 'situations', 'first', 'getting', 'second', 'loosing'], tags=[953]),
#  TaggedDocument(words=['moment', 'dayhas', 'valuemorning', 'brings', 'hopeafternoon', 'brings', 'faithevening', 'brings', 'luvnight', 'brings', 'restwish', 'u', 'find', 'todaygood', 'morning'], tags=[954]),
#  TaggedDocument(words=['well', 'join', 'ltgt', 'bus'], tags=[955]),
#  TaggedDocument(words=['yeah', 'probably', 'sure', 'ilol', 'let', 'u', 'know', 'personally', 'wuldnt', 'bother', 'ur', 'goin', 'mite', 'well'], tags=[956]),
#  TaggedDocument(words=['gsoh', 'good', 'spam', 'ladiesu', 'could', 'b', 'male', 'gigolo', '2', 'join', 'uks', 'fastest', 'growing', 'mens', 'club', 'reply', 'oncall', 'mjzgroup', '087143423992stop', 'reply', 'stop', 'msgå', '150rcvd'], tags=[957]),
#  TaggedDocument(words=['dont', 'want', 'hear', 'anything'], tags=[958]),
#  TaggedDocument(words=['come', 'guoyang', 'go', 'n', 'tell', 'u', 'told'], tags=[959]),
#  TaggedDocument(words=['remember', 'day'], tags=[960]),
#  TaggedDocument(words=['first', 'strike', 'red', 'one', 'bird', 'antelope', 'begin', 'toplay', 'fieldof', 'selfindependence', 'believe', 'flower', 'contention', 'growrandom'], tags=[961]),
#  TaggedDocument(words=['well', 'great', 'weekend'], tags=[962]),
#  TaggedDocument(words=['free', 'ring', 'tone', 'text', 'polys', '87131', 'every', 'week', 'get', 'new', 'tone', '0870737910216yrs', 'å', '150wk'], tags=[963]),
#  TaggedDocument(words=['uncle', 'boye', 'need', 'movies', 'oh', 'guide', 'plus', 'know', 'torrents', 'particularly', 'legal', 'system', 'slowing', 'gr8', 'day', 'plus', 'started', 'cos', 'dont', 'meet', 'online', 'honey', 'moon'], tags=[964]),
#  TaggedDocument(words=['ever', 'thought', 'living', 'good', 'life', 'perfect', 'partner', 'txt', 'back', 'name', 'age', 'join', 'mobile', 'community', '100psms'], tags=[965]),
#  TaggedDocument(words=['lol', 'oops', 'sorry', 'fun', ''], tags=[966]),
#  TaggedDocument(words=['seeing', 'missed', 'call', 'dear', 'brother', 'gr8', 'day'], tags=[967]),
#  TaggedDocument(words=['im', 'going', 'buy', 'mums', 'present', 'ar'], tags=[968]),
#  TaggedDocument(words=['haha', 'awesome', 'might', 'need', 'take', 'doin', 'tonight'], tags=[969]),
#  TaggedDocument(words=['hi', '07734396839', 'ibh', 'customer', 'loyalty', 'offer', 'new', 'nokia6600', 'mobile', 'å', '10', 'txtauctiontxt', 'wordstart', 'no81151', 'get', 'now4t'], tags=[970]),
#  TaggedDocument(words=['watch', 'lor', 'saw', 'swatch', 'one', 'thk', 'quite', 'ok', 'ard', '116', 'need', '2nd', 'opinion', 'leh'], tags=[971]),
#  TaggedDocument(words=['oh', 'really', 'perform', 'write', 'paper', 'go', 'movie', 'home', 'midnight', 'huh'], tags=[972]),
#  TaggedDocument(words=['dear', 'umma', 'called', ''], tags=[973]),
#  TaggedDocument(words=['kkwhy', 'cant', 'come', 'search', 'job'], tags=[974]),
#  TaggedDocument(words=['honeybee', 'said', 'im', 'sweetest', 'world', 'god', 'laughed', 'amp', 'said', 'waitu', 'havnt', 'met', 'person', 'reading', 'msg', 'moral', 'even', 'god', 'crack', 'jokes', 'gmgngegn'], tags=[975]),
#  TaggedDocument(words=['si', 'si', 'think', 'ill', 'go', 'make', 'oreo', 'truffles'], tags=[976]),
#  TaggedDocument(words=['im', 'free'], tags=[977]),
#  TaggedDocument(words=['hey', 'theres', 'veggie', 'pizza', ''], tags=[978]),
#  TaggedDocument(words=['raviyog', 'peripherals', 'bhayandar', 'east'], tags=[979]),
#  TaggedDocument(words=['dun', 'thk', 'ill', 'quit', 'yet', 'hmmm', 'go', 'jazz', 'yogasana', 'oso', 'go', 'meet', 'em', 'lessons', 'den', ''], tags=[980]),
#  TaggedDocument(words=['sorry', 'ill', 'call', 'later'], tags=[981]),
#  TaggedDocument(words=['oh', 'icic', 'k', 'lor', 'den', 'meet', 'day'], tags=[982]),
#  TaggedDocument(words=['still', 'checked', 'da', ''], tags=[983]),
#  TaggedDocument(words=['hot', 'n', 'horny', 'willing', 'live', 'local', 'text', 'reply', 'hear', 'strt', 'back', '150p', 'per', 'msg', 'netcollex', 'ltdhelpdesk', '02085076972', 'reply', 'stop', 'end'], tags=[984]),
#  TaggedDocument(words=['yuou', 'working', 'getting', 'pc', 'moms', 'find', 'spot', 'would', 'work', 'need'], tags=[985]),
#  TaggedDocument(words=['customer', 'loyalty', 'offerthe', 'new', 'nokia6650', 'mobile', 'å', '10', 'txtauction', 'txt', 'word', 'start', '81151', 'get', '4tctxt', 'tc', '150pmtmsg'], tags=[986]),
#  TaggedDocument(words=['thats', 'haf', 'combine', 'n', 'c', 'lor'], tags=[987]),
#  TaggedDocument(words=['im', 'home', 'please', 'call'], tags=[988]),
#  TaggedDocument(words=['seeing'], tags=[989]),
#  TaggedDocument(words=['tell', 'dear', 'happen', 'talking', 'like', 'alian'], tags=[990]),
#  TaggedDocument(words=['lemme', 'know', 'swing', 'pick', 'im', 'free', 'basically', 'time', '1', 'semester'], tags=[991]),
#  TaggedDocument(words=['free', 'msg', 'ringtonefrom', 'httptms', 'widelivecomindex', 'wmlid1b6a5ecef91ff937819firsttrue180430jul05'], tags=[992]),
#  TaggedDocument(words=['guess', 'could', 'good', 'excuse', 'lol'], tags=[993]),
#  TaggedDocument(words=['haha', 'thinkin'], tags=[994]),
#  TaggedDocument(words=['yeah', 'wheres', 'class'], tags=[995]),
#  TaggedDocument(words=['k', 'sent'], tags=[996]),
#  TaggedDocument(words=['dont', 'think', 'spatula', 'hands'], tags=[997]),
#  TaggedDocument(words=['cool', 'shall', 'go', 'see', 'go', 'tip', 'anyway', 'home', 'got', 'something', 'drop', 'later', 'lets', 'go', 'town', 'tonight', 'maybe', 'mum', 'take', 'us'], tags=[998]),
#  TaggedDocument(words=['cant', 'pick', 'phone', 'right', 'pls', 'send', 'message'], tags=[999]),
#  ...]

# %%
X_test[0:5]
# Out:
# 3329                          [send, yettys, number, pls]
# 1632    [hello, little, party, animal, thought, id, bu...
# 3235    [aight, text, youre, back, mu, ill, swing, nee...
# 3082                           [kkhow, training, process]
# 1264                                    [see, half, hour]
# Name: txt_clean, dtype: object

# %%
d2v = gensim.models.Doc2Vec(tag_train, vector_size = 50, window = 2, min_count = 2 )

# %%
X_train_d2v = [d2v.infer_vector(text.words) for text in tag_train]
X_test_d2v = [d2v.infer_vector(text.words) for text in tag_test]

# %%
print(X_train_d2v[0])
# Out:
# [ 0.00210781 -0.01025606  0.00424152  0.00024143 -0.00917417 -0.00439115
#   0.00161037  0.02572165 -0.02221104 -0.01134223  0.00095406 -0.02488241
#  -0.00110105  0.01128565 -0.00049442  0.00772907  0.02609073  0.00314334
#  -0.01531209 -0.01115839 -0.00600235  0.01197011  0.01796303 -0.01073938
#   0.01127774  0.00446393 -0.00327941 -0.00060531 -0.00953925 -0.00706836
#  -0.00897983 -0.0018637  -0.0016146   0.011136   -0.00790186  0.00457287
#   0.00237767 -0.00195308  0.01756881 -0.0118155   0.02458095 -0.0097932
#   0.00855546  0.01297083  0.01960312 -0.0118759  -0.00112738 -0.01837532
#   0.00637462  0.01632589]

# %% [markdown]
# ## Applying Random Forest Classifier

# %%
rf_d2v = RandomForestClassifier()
rf_d2v_model = rf_d2v.fit(X_train_d2v,y_train.values.ravel())

# %%
y_pred = rf_d2v_model.predict(X_test_d2v)

# %%
precision  = precision_score(y_test,y_pred)
recall  = recall_score(y_test,y_pred)

# %% [markdown]
# ## Applying LSTM

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)
X_train_tokenized = tokenizer.texts_to_sequences(X_train)
X_test_tokenized = tokenizer.texts_to_sequences(X_test)

# %%
len(tokenizer.index_word)
# Out:
# 8328

# %%
X_train_padded = pad_sequences(X_train_tokenized, 50)
X_test_padded = pad_sequences(X_test_tokenized, 50)

# %% [markdown]
# Making precision and recall functions

# %%
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Dense,Embedding,LSTM
from tensorflow.keras.models import Sequential

# %%
def precision_m(y_true,y_pred):
    
    tp = K.sum(K.round(K.clip(y_true*y_pred,0,1)))
    pp = K.sum(K.round(K.clip(y_pred,0,1))) #predicted postives
    precison = tp/(pp*K.epsilon())
    return recall

def recall_m(y_true,y_pred):
    
    tp = K.sum(K.round(K.clip(y_true*y_pred,0,1)))
    ap = K.sum(K.round(K.clip(y_true,0,1))) #actual positives
    recall = tp/(ap*K.epsilon())
    return recall

# %%
model = Sequential()

model.add(Embedding(len(tokenizer.index_word)+1,32))
model.add(LSTM(32, dropout = 0, recurrent_dropout = 0 ))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, None, 32)          266528
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 275,937
# Trainable params: 275,937
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',
             loss = 'binary_crossentropy',
             metrics = ['accuracy',precision_m,recall_m])

# %%
history = model.fit(X_train_padded, y_train, batch_size = 32, epochs = 5,
                   validation_data = (X_test_padded,y_test))
# Out:
# Epoch 1/5
# 140/140 [==============================] - 6s 25ms/step - loss: 0.4463 - accuracy: 0.8380 - precision_m: 0.5667 - recall_m: nan - val_loss: 0.0917 - val_accuracy: 0.9776 - val_precision_m: 0.5667 - val_recall_m: 8464285.0000
# Epoch 2/5
# 140/140 [==============================] - 3s 20ms/step - loss: 0.0322 - accuracy: 0.9914 - precision_m: 0.5667 - recall_m: nan - val_loss: 0.0807 - val_accuracy: 0.9794 - val_precision_m: 0.5667 - val_recall_m: 8521428.0000
# Epoch 3/5
# 140/140 [==============================] - 3s 20ms/step - loss: 0.0085 - accuracy: 0.9988 - precision_m: 0.5667 - recall_m: nan - val_loss: 0.0832 - val_accuracy: 0.9794 - val_precision_m: 0.5667 - val_recall_m: 8864285.0000
# Epoch 4/5
# 140/140 [==============================] - 3s 18ms/step - loss: 0.0049 - accuracy: 0.9992 - precision_m: 0.5667 - recall_m: nan - val_loss: 0.0861 - val_accuracy: 0.9821 - val_precision_m: 0.5667 - val_recall_m: 8900000.0000
# Epoch 5/5
# 140/140 [==============================] - 2s 18ms/step - loss: 0.0013 - accuracy: 0.9998 - precision_m: 0.5667 - recall_m: nan - val_loss: 0.0821 - val_accuracy: 0.9821 - val_precision_m: 0.5667 - val_recall_m: 9042857.0000
